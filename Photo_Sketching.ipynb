# %%
import cv2 as cv
from IPython.display import display
from PIL import Image

# %%
img = cv.imread('faces.jpg',1)
sketch = cv.pencilSketch(img)
cv.imshow('cat',sketch[1])
cv.waitKey(0)
cv.destroyAllWindows()

# %%
i = Image.open('cat.jpg')
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=273x185 at 0x21AC0F3F040>

# %%
Image.fromarray(img)
# Out:
# <PIL.Image.Image image mode=L size=273x185 at 0x2CDCEABF220>

# %%
img
# Out:
# array([[[ 28,  35,  44],
#         [ 28,  35,  44],
#         [ 28,  35,  44],
#         ...,
#         [178, 197, 212],
#         [178, 197, 212],
#         [177, 195, 212]],
#
#        [[ 28,  35,  44],
#         [ 28,  35,  44],
#         [ 29,  36,  45],
#         ...,
#         [178, 197, 212],
#         [178, 197, 212],
#         [177, 195, 212]],
#
#        [[ 28,  35,  44],
#         [ 29,  36,  45],
#         [ 29,  36,  45],
#         ...,
#         [178, 197, 212],
#         [178, 197, 212],
#         [177, 195, 212]],
#
#        ...,
#
#        [[ 19,  16,  11],
#         [ 19,  16,  11],
#         [ 23,  17,  12],
#         ...,
#         [120, 136, 149],
#         [120, 136, 149],
#         [120, 136, 149]],
#
#        [[ 19,  16,  11],
#         [ 19,  16,  11],
#         [ 23,  17,  12],
#         ...,
#         [120, 136, 149],
#         [120, 136, 149],
#         [120, 136, 149]],
#
#        [[ 16,  13,   8],
#         [ 20,  17,  12],
#         [ 25,  19,  14],
# ...

# %%
img
# Out:
# array([[ 37,  37,  37, ..., 199, 199, 198],
#        [ 37,  37,  38, ..., 199, 199, 198],
#        [ 37,  38,  38, ..., 199, 199, 198],
#        ...,
#        [ 15,  15,  16, ..., 138, 138, 138],
#        [ 15,  15,  16, ..., 138, 138, 138],
#        [ 12,  16,  18, ..., 136, 136, 137]], dtype=uint8)

# %%
shape(sketch)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-e8f9bddc1724> in <module>
# ----> 1 shape(sketch)
#
# NameError: name 'shape' is not defined

# %%
Image.fromarray(sketch[1])
# Out:
# <PIL.Image.Image image mode=RGB size=273x185 at 0x2CDD1270F70>

# %%
help(cv.pencilSketch)
# Out:
# Help on built-in function pencilSketch:
#
# pencilSketch(...)
#     pencilSketch(src[, dst1[, dst2[, sigma_s[, sigma_r[, shade_factor]]]]]) -> dst1, dst2
#     .   @brief Pencil-like non-photorealistic line drawing
#     .
#     .   @param src Input 8-bit 3-channel image.
#     .   @param dst1 Output 8-bit 1-channel image.
#     .   @param dst2 Output image with the same size and type as src.
#     .   @param sigma_s %Range between 0 to 200.
#     .   @param sigma_r %Range between 0 to 1.
#     .   @param shade_factor %Range between 0 to 0.1.
